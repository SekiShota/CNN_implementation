# %% [markdown]
# * 画像を読み込む
# * 顔検出
# * モデルで予測
# * 結果の表示

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from face_rectangle import get_face_rect

# %%
#モデル読み込み
from keras.models import load_model
model=load_model('./images/model_asutama.h5')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 30, 30, 32)       0
#  )
#
#  dropout (Dropout)           (None, 30, 30, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 13, 13, 64)        0
#
#  flatten (Flatten)           (None, 10816)             0
#
#  dense (Dense)               (None, 256)               2769152
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 2,834,977
# Trainable params: 2,834,977
# Non-trainable params: 0
# _________________________________________________________________

# %%
#テスト画像で検証
from PIL import Image

def detection(file):
    labels=["齋藤飛鳥", "玉森裕太"]
    #元の画像
    test_img=cv2.imread(file)
    test_img=cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB)
    
    #元画像から顔部分切り取った画像
    face_img, d=get_face_rect(file)
    face_img=cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB)
    plt.imshow(face_img)
    plt.axis('off')
    plt.show()
    
    #データの型変換
    x_test=np.asarray(face_img)
    x_test=x_test.reshape(-1, 64, 64, 3)
    
    #元画像に顔部分の矩形を描画
    x1=int(d.left())
    y1=int(d.top())
    x2=int(d.right())
    y2=int(d.bottom())
    cv2.rectangle(test_img, (x1, y1), (x2, y2), color=(255,0,0), thickness=5)
    plt.imshow(test_img)
    plt.axis('off')
    plt.show()
    
    #モデルでの予測
    pred=model.predict(x_test)[0]
    print(pred[0])
    if pred[0]<0.5: 
        print("予測結果：", labels[0])
    else:
        print("予測結果：", labels[1])

# %%
import glob

fname=glob.glob("./images/test1/*.jpg")
for f1 in fname:
    print(f1)
    detection(f1)
# Out:
# ./images/test1/S__2588694.jpg
# rectangles[[(379, 260) (646, 528)]]
# rectangle(379,260,646,528)
# 1/1 [==============================] - 0s 54ms/step
# 1.0
# 予測結果： 玉森裕太
# ./images/test1/S__2588696.jpg
# rectangles[[(390, 415) (613, 638)]]
# rectangle(390,415,613,638)
# 1/1 [==============================] - 0s 38ms/step
# 1.0
# 予測結果： 玉森裕太
# ./images/test1/S__2572316.jpg
# rectangles[[(455, 241) (776, 562)]]
# rectangle(455,241,776,562)
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 予測結果： 玉森裕太
# ./images/test1/S__2588693.jpg
# rectangles[[(438, 320) (706, 587)]]
# rectangle(438,320,706,587)
# 1/1 [==============================] - 0s 36ms/step
# 1.0
# 予測結果： 玉森裕太
# ./images/test1/S__2588703.jpg
# rectangles[[(195, 126) (285, 216)]]
# rectangle(195,126,285,216)
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 予測結果： 玉森裕太
# ./images/test1/S__2588702.jpg
# rectangles[[(180, 201) (366, 387)]]
# rectangle(180,201,366,387)
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 予測結果： 玉森裕太
# ./images/test1/S__2588700.jpg
# rectangles[[(344, 126) (434, 216)]]
# rectangle(344,126,434,216)
# 1/1 [==============================] - 0s 45ms/step
# 1.0
# 予測結果： 玉森裕太
# ./images/test1/S__2588705.jpg
# rectangles[[(184, 116) (339, 270)]]
# rectangle(184,116,339,270)
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 予測結果： 玉森裕太
# ./images/test1/S__2588704.jpg
# rectangles[[(167, 81) (322, 236)]]
# rectangle(167,81,322,236)
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 予測結果： 玉森裕太
# ./images/test1/S__2588699.jpg
# rectangles[[(153, 139) (282, 268)]]
# rectangle(153,139,282,268)
# 1/1 [==============================] - 0s 42ms/step
# 1.0
# 予測結果： 玉森裕太
# ./images/test1/S__2588698.jpg
# rectangles[[(225, 211) (354, 340)]]
# rectangle(225,211,354,340)
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 予測結果： 玉森裕太

# %%
fname=glob.glob("./images/test0/*.png")
for f0 in fname:
    print(f0)
    detection(f0)
# Out:
# ./images/test0/IMG_1684.png
# rectangles[[(572, 160) (758, 345)]]
# rectangle(572,160,758,345)
# 1/1 [==============================] - 0s 33ms/step
# 0.9999805
# 予測結果： 玉森裕太
# ./images/test0/IMG_1532.png
# rectangles[[(799, 366) (985, 552)]]
# rectangle(799,366,985,552)
# 1/1 [==============================] - 0s 36ms/step
# 1.0
# 予測結果： 玉森裕太
# ./images/test0/IMG_1650.png
# rectangles[[(494, 184) (648, 339)]]
# rectangle(494,184,648,339)
# 1/1 [==============================] - 0s 34ms/step
# 0.0
# 予測結果： 齋藤飛鳥
# ./images/test0/IMG_1365.png
# rectangles[[(438, 201) (706, 468)]]
# rectangle(438,201,706,468)
# 1/1 [==============================] - 0s 33ms/step
# 0.0
# 予測結果： 齋藤飛鳥
# ./images/test0/IMG_1466.png
# rectangles[[(683, 282) (812, 411)]]
# rectangle(683,282,812,411)
# 1/1 [==============================] - 0s 29ms/step
# 0.0
# 予測結果： 齋藤飛鳥
# ./images/test0/IMG_1488.png
# rectangles[[(706, 171) (973, 439)]]
# rectangle(706,171,973,439)
# 1/1 [==============================] - 0s 39ms/step
# 1.0
# 予測結果： 玉森裕太
