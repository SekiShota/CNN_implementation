# %%
#画像ファイルを読んでNumpy形式に変換
#画像にラベルをつけて保存

#保存ファイル名
#利用する画像枚数
#画像サイズ
#画像データ
#ラベルデータ

def main():
    #各画像フォルダを読む
    #ファイルへ保存
    
    
def glob_files(path, label):
    #画像ファイルを読む
    #色空間をRGB
    #サイズ変更

# %%
#images/train/jun_matsumoto/のファイル名変更
import glob

path="images/train/jun_matsumoto/*.jpg"
glob.glob(path)
# for p in path:
#     print(p)
# Out:
# ['images/train/jun_matsumoto/000152.jpg',
#  'images/train/jun_matsumoto/000146.jpg',
#  'images/train/jun_matsumoto/000026.jpg',
#  'images/train/jun_matsumoto/000032.jpg',
#  'images/train/jun_matsumoto/000033.jpg',
#  'images/train/jun_matsumoto/000027.jpg',
#  'images/train/jun_matsumoto/000147.jpg',
#  'images/train/jun_matsumoto/000153.jpg',
#  'images/train/jun_matsumoto/000179.jpg',
#  'images/train/jun_matsumoto/000145.jpg',
#  'images/train/jun_matsumoto/000151.jpg',
#  'images/train/jun_matsumoto/000019.jpg',
#  'images/train/jun_matsumoto/000031.jpg',
#  'images/train/jun_matsumoto/000025.jpg',
#  'images/train/jun_matsumoto/000024.jpg',
#  'images/train/jun_matsumoto/000030.jpg',
#  'images/train/jun_matsumoto/000018.jpg',
#  'images/train/jun_matsumoto/000150.jpg',
#  'images/train/jun_matsumoto/000144.jpg',
#  'images/train/jun_matsumoto/000178.jpg',
#  'images/train/jun_matsumoto/000140.jpg',
#  'images/train/jun_matsumoto/000154.jpg',
# ...
